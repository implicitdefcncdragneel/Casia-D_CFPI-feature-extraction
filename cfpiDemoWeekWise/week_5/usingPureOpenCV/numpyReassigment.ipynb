# %%
import numpy as np

import cv2

import matplotlib.pyplot as plt
# %matplotlib inLine

# %%
img_0=cv2.imread("datasetPerson24/demo8.jpg")
img_0_1=cv2.cvtColor(img_0,cv2.COLOR_BGR2RGB)

# %%
img_1=cv2.imread("datasetPerson24/demo9.jpg")
img_1_1=cv2.cvtColor(img_1,cv2.COLOR_BGR2RGB)

# %%
img_0_1.shape
# Out:
# (121, 47, 3)

# %%
img_0_1_1=cv2.resize(img_0_1,(50,130))

# %%
img_1_1.shape
# Out:
# (118, 49, 3)

# %%
img_1_1_1=cv2.resize(img_1_1,(50,130))

# %%
blended =cv2.addWeighted(src1=img_0_1_1,alpha=0.8,src2=img_1_1_1,beta=0.5,gamma=10)

# %%
plt.imshow(blended)

# %%
#####################################################
#Numpy Reassigement 
#####################################################

# %%
img_0=cv2.imread("datasetPerson24/demo8.jpg")
img_0_1=cv2.cvtColor(img_0,cv2.COLOR_BGR2RGB)

img_1=cv2.imread("datasetPerson24/demo9.jpg")
img_1_1=cv2.cvtColor(img_1,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img_0_1)

# %%
plt.imshow(img_1_1)

# %%
large_img =img_0_1
small_img =img_1_1

# %%
x_offset=0
y_offset=0

# %%
x_end =x_offset +small_img.shape[1]
y_end =y_offset +small_img.shape[0]

# %%
#large_img[y_offset:y_end,x_offset:x_end]=small_img

# %%
######################################
#Image Blending
######################################

# %%
img_0=cv2.imread("datasetPerson24/demo8.jpg")
img_0_1=cv2.cvtColor(img_0,cv2.COLOR_BGR2RGB)

img_1=cv2.imread("datasetPerson24/demo9.jpg")
img_1_1=cv2.cvtColor(img_1,cv2.COLOR_BGR2RGB)

# %%
img1Resize=cv2.resize(img_0_1,(50,130))

# %%
img2Resize=cv2.resize(img_1_1,(25,65))

# %%
plt.imshow(img1Resize)

# %%
plt.imshow(img2Resize)

# %%
#################################
#regin of interrest
#################################

# %%
x_offset=50-30
y_offset=130-65

# %%
rows,cols,channels =img2Resize.shape

# %%
rows
# Out:
# 65

# %%
cols
# Out:
# 25

# %%
channels
# Out:
# 3

# %%
roi=img1Resize[y_offset:,x_offset:]

# %%
plt.imshow(roi)

# %%
img2gray=cv2.cvtColor(img2Resize,cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(img2gray,cmap='gray')

# %%
msk_inv=cv2.bitwise_not(img2gray)

# %%
plt.imshow(msk_inv,cmap="gray")

# %%
msk_inv.shape
# Out:
# (65, 25)

# %%
white_background=np.full(msk_inv.shape,255,dtype=np.uint8)

# %%
white_background
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
plt.imshow(white_background)

# %%
bk=cv2.bitwise_or(white_background,white_background,mask=msk_inv)

# %%
bk.shape
# Out:
# (65, 25)

# %%
plt.imshow(bk)
